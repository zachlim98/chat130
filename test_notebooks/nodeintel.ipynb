# %%
from llama_index.readers.base import BaseReader
from llama_index.readers.schema.base import Document
from azure.ai.formrecognizer import DocumentAnalysisClient
from azure.core.credentials import AzureKeyCredential
from typing import Any, Dict, List, Optional
from fastapi import  UploadFile

class AzureDocIntelligenceReader(BaseReader):
    def __init__(self,azure_api_endpoint:str,azure_api_key:str,model_id:Optional[str] = "prebuilt-read",per_page:Optional[bool]=True) -> None:
        try:
            self.client = DocumentAnalysisClient(endpoint=azure_api_endpoint, credential=AzureKeyCredential(azure_api_key))
        except Exception as e:
            print("the following error occured while creating azure client ",e)
        self.model_id = model_id
        self.per_page = per_page
    
     def load_data(self,document:UploadFile) -> List[Document]:
        data =  document
        documents = []
        try:
            poller = self.client.begin_analyze_document(self.model_id, data)
            result = poller.result()
            if self.per_page:
                for page in result.pages:
                    content = "\n".join([line.content for line in page.lines])
                    documents.append(Document(text=content,metadata={"total_pages":len(result.pages),"page":page.page_number,"filename":document.filename}))
                return documents
            else:
                documents.append(Document(text=result.content))

                print(documents)
                return documents

        except Exception as e:
            print("the following error occured while loading data ",e)
            return None

# %%
import os
from azure.ai.formrecognizer import DocumentAnalysisClient
from azure.core.credentials import AzureKeyCredential

# %%
test_pdf = open("../data/124/EEM FINAL caa201221.pdf", "rb")
pdf_bytes = test_pdf.read()
test_pdf.close()

# %%
endpoint = "https://rsaf-document-intelligence.cognitiveservices.azure.com/"
key = "9646643789c44f279072a7ebbc8a42cd"

from llama_index.node_parser import SimpleNodeParser
from llama_index import VectorStoreIndex

node_parser = SimpleNodeParser.from_defaults(
    chunk_size=512, chunk_overlap=0)

azure_doc_loader = AzureDocIntelligenceReader(azure_api_endpoint=endpoint,azure_api_key=key,model_id="prebuilt-layout")

def pdf_to_nodes(file: UploadFile) -> str:
    # document = loader.load(file_path=pdf_path, metadata=True)
    document = azure_doc_loader.load_data(file)
    nodes = node_parser.get_nodes_from_documents(document)
    print(nodes)
    return nodes

# %%
pdf_to_nodes(pdf_bytes)
# Out:
# [TextNode(id_='8558d6fd-f02c-423e-b542-b17f92a3f196', embedding=None, metadata={'total_pages': 319, 'page': 1}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='faa80fa7-2f39-4c79-a364-57e8115f3624', node_type=None, metadata={'total_pages': 319, 'page': 1}, hash='f9918839cbc66be598c4ab71913b8f8ba164f6dedc3f51a5f76477cdf323cccd')}, hash='f9918839cbc66be598c4ab71913b8f8ba164f6dedc3f51a5f76477cdf323cccd', text='OFFICIAL (CLOSED)\n124 SQUADRON\nREPUBLIC OF SINGAPORE AIR FORCE\nEC120B\nEMPLOYMENT\nMANUAL\ni\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='c1626008-388c-4de4-9253-a8713fbba37b', embedding=None, metadata={'total_pages': 319, 'page': 2}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='b8ea1c34-62d6-4df0-986c-a5b3f2de9688', node_type=None, metadata={'total_pages': 319, 'page': 2}, hash='9ab0616c827bf5c22594b9549244a1dc9ff0054cc0139642d3b0c5429c76bbe0')}, hash='9ab0616c827bf5c22594b9549244a1dc9ff0054cc0139642d3b0c5429c76bbe0', text='OFFICIAL (CLOSED)\nAMENDMENT LIST\nS/No.\nDate\nAmendment\nList Number\nChapter / Section\nRemarks\nii\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='2dc44e60-1f0c-4016-8c69-d86127abb92f', embedding=None, metadata={'total_pages': 319, 'page': 3}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='7617af3d-2806-448e-ad28-51913de57541', node_type=None, metadata={'total_pages': 319, 'page': 3}, hash='5f92aacf81232f131e428f0ee0f84d4fa4a75ece9479a0ee9e1f16f5b28112fa')}, hash='5f92aacf81232f131e428f0ee0f84d4fa4a75ece9479a0ee9e1f16f5b28112fa', text="OFFICIAL (CLOSED)\nPREFACE\n1.\nThe EC120B Employment Manual (EEM) provides details on the operation\nand conduct of manoeuvres on the EC120B helicopter. It is the main reference\nmanual for the Rotary Wing Course and aims to provide details on the 'how' and\n'why' of techniques and manoeuvres on the EC120B.\n2.\nThe manual is divided into the following parts:\na.\nBasic Handling\nb.\nAdvanced Handling\nc.\nApplied Flying\nd.\nInstrument and Night Flying\ne.\nEmergency Handling\n3.\nThe information contained within is sourced from various publications\nincluding, but not limited to, the RWC trainee study guide, the Central Flying\nSchool AP3456 and US Army helicopter manuals. The manual is also to be read\nin close conjunction with the following:\na.\nCentral Flying School, AP3456\nb.\nEC120B Standing Order and Standard Operating Procedures\nc.\nEC120B Flight Manual (FLM)\nd.\nRSAF Rotary Wings Syllabus\ne.\nHeliG Publications\nf.\nAFOD\ng.\nRSAF ATCI\nh.\nRSAF Instrument Flying Reference Manual\n4.\nSuggestions for amendments and new insertions are to be forwarded to CO\n124 SQN.\nCommanding Officer\n124 SQN\nEffective Date\n: Dec 2021\nReview Date\n: Dec 2025\niii\nOFFICIAL (CLOSED)", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'), TextNode(id_='49cab3cc-760a-41b7-8e70-786d128da089', embedding=None, metadata={'total_pages': 319, 'page': 4}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='592db895-9b20-4444-a129-990bfa28ee65', node_type=None, metadata={'total_pages': 319, 'page': 4}, hash='6e78194beb370b41c704bbf632b5ab39538e2f8867b685f89cfcd18aa476ff2e')}, hash='6e78194beb370b41c704bbf632b5ab39538e2f8867b685f89cfcd18aa476ff2e', text='OFFICIAL (CLOSED)\nCONTENTS\nPART A - BASIC HANDLING\nCHAPTER 1 - Introduction And Familiarisation\n1-1\nCHAPTER 2 - Ef ...
# [TextNode(id_='8558d6fd-f02c-423e-b542-b17f92a3f196', embedding=None, metadata={'total_pages': 319, 'page': 1}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='faa80fa7-2f39-4c79-a364-57e8115f3624', node_type=None, metadata={'total_pages': 319, 'page': 1}, hash='f9918839cbc66be598c4ab71913b8f8ba164f6dedc3f51a5f76477cdf323cccd')}, hash='f9918839cbc66be598c4ab71913b8f8ba164f6dedc3f51a5f76477cdf323cccd', text='OFFICIAL (CLOSED)\n124 SQUADRON\nREPUBLIC OF SINGAPORE AIR FORCE\nEC120B\nEMPLOYMENT\nMANUAL\ni\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='c1626008-388c-4de4-9253-a8713fbba37b', embedding=None, metadata={'total_pages': 319, 'page': 2}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='b8ea1c34-62d6-4df0-986c-a5b3f2de9688', node_type=None, metadata={'total_pages': 319, 'page': 2}, hash='9ab0616c827bf5c22594b9549244a1dc9ff0054cc0139642d3b0c5429c76bbe0')}, hash='9ab0616c827bf5c22594b9549244a1dc9ff0054cc0139642d3b0c5429c76bbe0', text='OFFICIAL (CLOSED)\nAMENDMENT LIST\nS/No.\nDate\nAmendment\nList Number\nChapter / Section\nRemarks\nii\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='2dc44e60-1f0c-4016-8c69-d86127abb92f', embedding=None, metadata={'total_pages': 319, 'page': 3}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='7617af3d-2806-448e-ad28-51913de57541', node_type=None, metadata={'total_pages': 319, 'page': 3}, hash='5f92aacf81232f131e428f0ee0f84d4fa4a75ece9479a0ee9e1f16f5b28112fa')}, hash='5f92aacf81232f131e428f0ee0f84d4fa4a75ece9479a0ee9e1f16f5b28112fa', text="OFFICIAL (CLOSED)\nPREFACE\n1.\nThe EC120B Employment Manual (EEM) provides details on the operation\nand conduct of manoeuvres on the EC120B helicopter. It is the main reference\nmanual for the Rotary Wing Course and aims to provide details on the 'how' and\n'why' of techniques and manoeuvres on the EC120B.\n2.\nThe manual is divided into the following parts:\na.\nBasic Handling\nb.\nAdvanced Handling\nc.\nApplied Flying\nd.\nInstrument and Night Flying\ne.\nEmergency Handling\n3.\nThe information contained within is sourced from various publications\nincluding, but not limited to, the RWC trainee study guide, the Central Flying\nSchool AP3456 and US Army helicopter manuals. The manual is also to be read\nin close conjunction with the following:\na.\nCentral Flying School, AP3456\nb.\nEC120B Standing Order and Standard Operating Procedures\nc.\nEC120B Flight Manual (FLM)\nd.\nRSAF Rotary Wings Syllabus\ne.\nHeliG Publications\nf.\nAFOD\ng.\nRSAF ATCI\nh.\nRSAF Instrument Flying Reference Manual\n4.\nSuggestions for amendments and new insertions are to be forwarded to CO\n124 SQN.\nCommanding Officer\n124 SQN\nEffective Date\n: Dec 2021\nReview Date\n: Dec 2025\niii\nOFFICIAL (CLOSED)", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='49cab3cc-760a-41b7-8e70-786d128da089', embedding=None, metadata={'total_pages': 319, 'page': 4}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='592db895-9b20-4444-a129-990bfa28ee65', node_type=None, metadata={'total_pages': 319, 'page': 4}, hash='6e78194beb370b41c704bbf632b5ab39538e2f8867b685f89cfcd18aa476ff2e')}, hash='6e78194beb370b41c704bbf632b5ab39538e2f8867b685f89cfcd18aa476ff2e', text='OFFICIAL (CLOSED)\nCONTENTS\nPART A - BASIC HANDLING\nCHAPTER 1 - Introduction And Familiarisation\n1-1\nCHAPTER 2 - Effects Of Control\n2-1\nCHAPTER 3 - Straight & Level, Acceleration & Deceleration\n3-1\nCHAPTER 4 - Climbing and Descending, Turns\n4-1\nCHAPTER 5 - Basic Autorotation\n5-1\nCHAPTER 6 - Hovering\n6-1\nCHAPTER 7 - Take-Off And Landing\n7-1\nCHAPTER 8 - Ground Manoeuvres - Sideways, Backwards Flight And Spot\nTurns\n8-1\nCHAPTER 9 - Basic Transition\n9-1\nCHAPTER 10 - Circuits\n10-1\nPART B - ADVANCED HANDLING\nCHAPTER 11 - Advanced Autorotation\n11-1\nCHAPTER 12 - Practice Forced Landing\n12-1\nCHAPTER 13 - Advanced Transitions\n13-1\nCHAPTER 14 - Advanced Take-Off And Landing\n14-1\nPART C - APPLIED FLYING\nCHAPTER 15 - Navigation\n15-1\nCHAPTER 16- Quickstops\n16-1\nCHAPTER 17 - Terrain Flight\n17-1\nCHAPTER 18 - Confined Area\n18-1\nCHAPTER 19 - Basic Tactical Formation\n19-1\nPART D - INSTRUMENT AND NIGHT FLYING\nCHAPTER 20 - Instrument Flying\n20-1\nCHAPTER 21 - Night Flying\n21-1\nPART E - EMERGENCY HANDLING\nCHAPTER 22 - Emergency Handling\n22-1\niv\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='2e9b4399-11b1-4581-b8c0-9b476d15429c', embedding=None, metadata={'total_pages': 319, 'page': 5}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='ae01406d-9bdf-4759-9a09-6625b985955c', node_type=None, metadata={'total_pages': 319, 'page': 5}, hash='d646dafd1afd239c0b98a2088142ff67127eae7411f6e5cb1ee10ac693335350')}, hash='d646dafd1afd239c0b98a2088142ff67127eae7411f6e5cb1ee10ac693335350', text='OFFICIAL (CLOSED)\nPART A:\nBASIC\nHANDLING\nA\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='3c303a95-4539-4527-8738-7228dd92ee6c', embedding=None, metadata={'total_pages': 319, 'page': 6}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='9c9fc201-b3db-4aa0-8628-94c333a10d37', node_type=None, metadata={'total_pages': 319, 'page': 6}, hash='8a82eb41029aa6f8feec880da526de2fb98763e20badf07a31e9c7ea922dcb9e'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='a9fa561d-2516-4b7c-a39a-66643d9df8a2', node_type=None, metadata={'total_pages': 319, 'page': 6}, hash='0ded65fe7c5135ebbc6c81b93a884abd386b47836c47e71b799a16a059e1b203')}, hash='b14afc1f9886e7b2d174d5a935bac37216c8bc01b1079c0359da192c81a00acb', text='OFFICIAL (CLOSED)\nPART A\nCHAPTER 1\nINTRODUCTION AND FAMILIARISATION\nINTRODUCTION\n1.1\nThis chapter orientates crew, with a focus on RWC trainees, to the\nsquadron\'s administrative processes, preparation for flight training on the\nEC120B in Singapore and common practices and terms used in helicopter\noperations. In addition, an introduction to the EC120B helicopter and its unique\ncharacteristics is provided (See Annex A).\n1.2\nEEM. The EC employment manual serves to provide RWC trainees, QHIs\nand all crew operating the EC120B details of the conduct of manoeuvres along\nwith linking the application to basic helicopter principles of flight and providing\nthe context of the manoeuvre to application in helicopter operations. Each chapter\nemploys the "Who, What, When, Where, Why and How" framework in\nstructuring content. The structure and common terms used in the EEM are as\nfollows:\nTable 1-1: Generic EEM Structure\nSub-Topic\n5Ws and 1H\nDetails\nIntroduction and\nObjectives\nWhat\nThe key takeaways from the chapter.\nHelicopter Principles of\nFlight (HPOF)*\nWhy\nReferenced off the AP 3456, the HPOF\nfundamentals are expanded in relation to the\nmanoeuvre.\nExecution of Manoeuvres\nWhere and\nHow\nThe training space, steps and sequence to\nconduct the air exercise.\nContingencies,\nEmergencies watch areas\nWhat if and\nWhy?\nWatch areas when conducting the airex and\navoidance or recovery actions.\nCrew Resource\nManagement / Roles and\nResponsibilities\nWho?\nRoles and CRM responsibilities of the\nFlying Pilot (FP) and Non-flying Pilot\n(NFP).\nAirmanship\nWhat and\nWhere?\nAirmanship points that need to be closely\nwatched and adhered to.\nSupplementary\ninformation or Annexes*\nWhat and\nWhy?\nAdditional theoretical information\napplicable to helicopter operations or\nadditional knowledge required in\npreparation for operational helicopter flying.\n*applicable to certain chapters only\n1.3\nObjective.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='a9fa561d-2516-4b7c-a39a-66643d9df8a2', embedding=None, metadata={'total_pages': 319, 'page': 6}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='9c9fc201-b3db-4aa0-8628-94c333a10d37', node_type=None, metadata={'total_pages': 319, 'page': 6}, hash='8a82eb41029aa6f8feec880da526de2fb98763e20badf07a31e9c7ea922dcb9e'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='3c303a95-4539-4527-8738-7228dd92ee6c', node_type=None, metadata={'total_pages': 319, 'page': 6}, hash='b14afc1f9886e7b2d174d5a935bac37216c8bc01b1079c0359da192c81a00acb')}, hash='0ded65fe7c5135ebbc6c81b93a884abd386b47836c47e71b799a16a059e1b203', text='The objectives are to be; (1) familiar with flight administration\nprocesses, (2) familiar with sortie preparation requirements for training flights on\n1-1\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='54d87fb1-4089-4d93-a723-49499e50b55b', embedding=None, metadata={'total_pages': 319, 'page': 7}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='772dc3ac-d49a-4edf-874d-e876be9bd4fc', node_type=None, metadata={'total_pages': 319, 'page': 7}, hash='00bfc80e1df51409dd0172bed97167073333c1950a589667ca27da5a7e24c726'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='e6e04bda-b7d5-4ddd-9319-98593e94104a', node_type=None, metadata={'total_pages': 319, 'page': 7}, hash='dc1484955585e52182e1744ece92cbfffd89ad7dae73d0b9bac5be35d3771810')}, hash='00338425e1df2716b651459dac378db046065cfbcb9be45018bd7a005b683f27', text='OFFICIAL (CLOSED)\nthe RSAF EC120B (EC) and (3) familiar with terms and safety practices in\nhelicopter operations.\nGROUND PREPARATION\n1.4\nSortie preparation. Trainees (or pilots on course) are expected to have read\nand be familiar with orders and directives such as, but not limited to, AFOD,\nRSAF ATCI and RSAF Instrument Flying Reference Manual. In addition, all\ncrew to be conversant with the EC120B SOP, Standing Order, Risk Minimisation\nReview (RMR) measures, FTI publications and HeliG orders pertaining to local\nhelicopter flying operations. Preparation for a sortie begins with reading the\nrelevant chapter of the EEM, self-learning and revision through Flight Task\nIllustrator (FLTI), attending the mass brief and clarifying details pertaining to the\nair exercise. Where applicable, this will be followed by sorties on the EC120B\nFlight Training Device (simulator) after which crew are ready for the live flight.\nAs a norm, RWC trainees should have completed the requisite sortie preparation\na minimum of three events in advance of their current sortie.\nPRE-FLIGHT ADMINISTRATION\n1.5\nGo / No-Go. The "Go / No-Go" checklist system is employed to ensure\naircrew have achieved the necessary pre-requisites and/or currencies such as\nRAMS, survival drills, quizzes, egress drills etc. prior to flying. Following this,\nthe risk assessment matrix for the flight should be completed. It is the individual\naircrew\'s responsibility to ensure that their relevant currencies are accurately\nupdated on the Operations Management System (OMS)1 prior to flying.\na.\nBoldface and limitations quiz. In accordance with the AFOD,\nmonthly limitation quizzes and weekly emergency procedure (boldface)\nquizzes are to be completed before the start of flying. Boldface quizzes\ninvolve time-critical emergency checklist items that aircrew must commit\nto memory. The limitations quiz is to be completed on the first flying day\nof the month to refresh on aircraft operating limitations.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='e6e04bda-b7d5-4ddd-9319-98593e94104a', embedding=None, metadata={'total_pages': 319, 'page': 7}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='772dc3ac-d49a-4edf-874d-e876be9bd4fc', node_type=None, metadata={'total_pages': 319, 'page': 7}, hash='00bfc80e1df51409dd0172bed97167073333c1950a589667ca27da5a7e24c726'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='54d87fb1-4089-4d93-a723-49499e50b55b', node_type=None, metadata={'total_pages': 319, 'page': 7}, hash='00338425e1df2716b651459dac378db046065cfbcb9be45018bd7a005b683f27')}, hash='dc1484955585e52182e1744ece92cbfffd89ad7dae73d0b9bac5be35d3771810', text='Aircrew are to\nupdate the OMS Go / No-Go upon completion of the quizzes.\nb.\nRisk assessment matrix (RAMs). RAMs utilises the 5M model\n(Management, Man, Medium, Machine and Mission) to provide the\noverall risk assessment for a particular event or flight. It highlights\npotential watch areas for the mission and allows aircrew and Sqn\n1 This includes systems such as the TRIDENT II or ATOM.\n1-2\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='f5ecb30b-b694-4f62-8636-4063c23673d2', embedding=None, metadata={'total_pages': 319, 'page': 8}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='48cb2292-948b-47e0-a43a-cae13c119127', node_type=None, metadata={'total_pages': 319, 'page': 8}, hash='da42b14890d7f6ce15bc8cebda8d82e54ecfede339b5c14e308792f3a9cd0bb0'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='fcd1c73c-4fcb-42c5-92ed-20912a49e371', node_type=None, metadata={'total_pages': 319, 'page': 8}, hash='e50b87076419b7cf107a73df5c902b3ce0ec30bc994b98e0dbd2be5f7b457916')}, hash='3e04cd9ebe77cd15d14a8be8586bdda5774930c2f166ede493281051edd8a486', text='OFFICIAL (CLOSED)\nmanagement to mitigate risks should it be required. Crew will complete\nthe RAMs using the TRIDENT and highlight any medium / high risk score\nsorties with proposed mitigating factors to their QHIs or aircraft captains\nduring the pre-flight brief. These factors will be briefed to the Squadron\nExecutive Officer (SXO) with the necessary authorisation sought prior to\nstepping for flight.\n1.6\nSortie/mission brief. As a norm, the sortie brief should be scheduled at\nleast 1 hour prior to the planned take-off time. Crew are to check the flying\nprogramme the day prior and arrange an alternate briefing time with their QHI\nshould there be any schedule or time restrictions. The standard briefing format\nutilises the PAYMATESO acronym (See Table 1-2 for details). All RWC or\nsyllabus flights, including those with separate mission briefs (such as Tactical\nFormation), should cater time for a PAYMATESO brief at the individual aircraft\ncrew level.\nTable 1-2: 124 SQN Briefing Format\nP\nPersonal Equipment\nID tag, torchlight* and other issued items\nProfessional Equipment\nMap*, FRC, DVR, GPS, NVG*\nProtection Equipment\nSTASS, Mae West, Gloves etc.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='fcd1c73c-4fcb-42c5-92ed-20912a49e371', embedding=None, metadata={'total_pages': 319, 'page': 8}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='48cb2292-948b-47e0-a43a-cae13c119127', node_type=None, metadata={'total_pages': 319, 'page': 8}, hash='da42b14890d7f6ce15bc8cebda8d82e54ecfede339b5c14e308792f3a9cd0bb0'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='f5ecb30b-b694-4f62-8636-4063c23673d2', node_type=None, metadata={'total_pages': 319, 'page': 8}, hash='3e04cd9ebe77cd15d14a8be8586bdda5774930c2f166ede493281051edd8a486')}, hash='e50b87076419b7cf107a73df5c902b3ce0ec30bc994b98e0dbd2be5f7b457916', text="A\nAdministration\nCallsign, IFF, Manifest*\nY\nYou\nFlight and Survival Currency, Crew rest\nM\nMeteorology\nWeather updates, Airfield status, NOTAMS,\nIllumination*, Weather contingencies\nA\nAircraft\nTail No, Parking slot, Fuel state, Configuration, ADD/L2s,\nPerformance - AUW and Power requirements*\nT\nTime\nTraffic\nWalkout, Pre-flight, Crank, Take-off, Duration, Landing/\nRunning change\nAO traffic and de-confliction\nE\nExercise\nSortie / Mission Profile\nSortie / Mission Objectives\nS\nSafety\nHazards, CRM duties, Watch Areas / SII, Lessons learnt\nand Captains Brief\nO\nOthers - Areas of Concern,\nEmergency Discussion\nAny other factors which may impact the sortie profile\nEmergencies associated with the sortie profile\n* Where applicable\n1.7\nSXO (step) brief. Crew are to conduct a 'step' brief with the SXO prior to\nwalking for flight. Any specific areas of concern or watch areas must be briefed\nto the SXO. The SXO would provide the necessary guidance for the flight before\nthe authorising officer authorises the flight on the OMS.\n2 Acceptable Deferred Defect / Limitations.\n1-3\nOFFICIAL (CLOSED)", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='a33d0adf-2ea6-433e-bcf6-2128470cb2e6', embedding=None, metadata={'total_pages': 319, 'page': 9}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='0c478347-5e51-4cbe-8ca8-63f334c28834', node_type=None, metadata={'total_pages': 319, 'page': 9}, hash='8afcd8e70e4971249823fd9ce00d47fa6344252552e9d6fa1e3c33f38f1f8402'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='98cf1280-02bf-430c-8a56-c2208dcdeaee', node_type=None, metadata={'total_pages': 319, 'page': 9}, hash='051c0e7ac0958e1acba5a693cc0fb23d32ed34959724ab6c0551c1c2c36a9af3')}, hash='9af2d009fec13592ea76e8e526e480328c9892549aaaef93686222bff1945de3', text="OFFICIAL (CLOSED)\n1.8\nSign out / in aircraft. The aircraft captain will accept the helicopter from\nthe maintenance operations centre (MOC) by thoroughly checking and thereafter\nsigning the ST Tech Log (SAF 1400 equivalent). Crew must be cross check with\nthe information contained in the aircraft Acceptable Deferred Defect / Limitations\n(ADD/L) Log and Aircraft Maintenance Operating System (AMOS) before flight\nto ensure the aircraft related details are accurate. Crew must ensure the relevant\nservicing and work done on the aircraft is properly closed with the required\nauthorisation and paperwork complete. The SXO and AO should be updated of\nany deviations from pre-briefed/authorised aircraft configuration or ADD/L.\nFLIGHT OPERATIONS\n1.9\nWalk around checks. All pre-flight and post-flight walk around checks\nmust be conducted with reference to the EC120B Flight reference cards (FRC). A\nwalk around demonstration video is available in the FLTI for crews' preparation\nprior to flight.\n1.10 In-flight checks. Crew must commit all checks from pre-start to shut-down\nto memory before their first live flight. However, when in doubt, crew may refer\nto the FRC to ensure checks or steps are not missed. As part of the squadron's\ndeliberate action programme (DAP), the three step Identify-Verify-Execute (IVE)\naction is used in the activation of identified levers (e.g. rotor brake) and switches\n(e.g. Hyd Cut-off). Peculiar to helicopter operations, it is mandated that one pilot\nmust always maintain hands on the collective3 and cyclic and feet on pedals\nwhenever the blades are turning. As such, it is vital that crew responsibilities\nduring checks and in-flight are clearly briefed and strictly adhered to.\n1.11 Ground procedures. Aircrew are to adhere to personnel ground movement,\nengine start-up and ground taxy procedures as detailed in RSAF ATCI (SBAB),\nHeliG Orders and relevant squadron orders.\n1.12 Running change.", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='98cf1280-02bf-430c-8a56-c2208dcdeaee', embedding=None, metadata={'total_pages': 319, 'page': 9}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='0c478347-5e51-4cbe-8ca8-63f334c28834', node_type=None, metadata={'total_pages': 319, 'page': 9}, hash='8afcd8e70e4971249823fd9ce00d47fa6344252552e9d6fa1e3c33f38f1f8402'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='a33d0adf-2ea6-433e-bcf6-2128470cb2e6', node_type=None, metadata={'total_pages': 319, 'page': 9}, hash='9af2d009fec13592ea76e8e526e480328c9892549aaaef93686222bff1945de3')}, hash='051c0e7ac0958e1acba5a693cc0fb23d32ed34959724ab6c0551c1c2c36a9af3', text='Helicopters conduct crew running changes where\ncockpit and/or cabin crew change out with the engine running and blades turning.\nTo execute this process safely, norms and procedures are detailed in the EC120B\nSO.\na.\nSpecific process. Prior to approaching the helicopter, crew are to\nensure it has safely landed, indicated by an extinguished landing light. The\nincoming crew are to verify the tail number (also painted on the nose) and\nto look out for a thumbs up signal from the crew before approaching the\n3 Flying pilot can relinquish control from the collective when it is down and locked.\n1-4\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='51654934-580b-42cd-89e2-472eba9456cf', embedding=None, metadata={'total_pages': 319, 'page': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='dd4b8756-4215-48ea-b16f-647d5e6fccbd', node_type=None, metadata={'total_pages': 319, 'page': 10}, hash='684e4f4438e05f38a818d7df62cf57a6f2f4e98f5c1474926aff47e1ef44b824'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='71ae43ba-9743-4ef0-81c5-ae949fdffd16', node_type=None, metadata={'total_pages': 319, 'page': 10}, hash='9d25e490170a3b4976607ac5236f9178a03876a9cfc3d0ae48c4091454c4a0a0')}, hash='de0420f93b61bc3355c6030c6f3675cd96882aeb0c428b52379bad7e94ead9f2', text="OFFICIAL (CLOSED)\nhelicopter from either the 10 or 2 o'clock position only. Once at the\nhelicopter, incoming crew are to check the general condition of the\nfuselage and then the transmission deck for any signs of leak by looking\nthrough the openings of the engine cowling panel on both sides of the\nhelicopter. Aircrew are to avoid the tail rotor4 and not go any further\nbehind the engine exhaust. Crew are only to cross from port to starboard\nat the front of the helicopter, keeping close to the fuselage.\n1.13\nGround taxy. All radio phraseology should strictly be in accordance with\nRSAF R/T Manual. Crew must be conversant with all reporting points and airfield\noperations in Sembawang Air Base (SBAB) with specific attention to finger pier\nand main dispersal procedures and operations. Aircrew must be cautious when\noperating in high OAT and/or high AUW with tail wind conditions as the power\nrequired for hover would be significantly higher. The First Limit Instrument (FLI)\nis non-linear to collective application and therefore RWC trainees are to ask QHIs\nto follow through controls when raising the collective past 9.3 to 9.6 FLI (max\ncontinuous). Following the take-off to a hover, a leak check will need to be\ncompleted. At finger pier A, the helicopter will need to conduct a spot turn to the\ntaxy direction. For standardisation, turn the helicopter in the direction of any other\nhelicopter with blades turning else turn towards the direction of the prevailing\nwind. For standardisation on the taxy out, taxy north of Point November (N) and\nsouth of Point Sierra (S). The N/S reporting point ground markers are to be\nmaintained outside of the rotor disc area for obstacles clearance.\n1.14\nAirborne procedures. During the first sortie, a familiarisation of local\ntraining areas such as SBAB, Light Aircraft Training Area Alpha (LATA A) and\nMacRitchie will be conducted.\na.\nSingle-engine helicopter restrictions.", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='71ae43ba-9743-4ef0-81c5-ae949fdffd16', embedding=None, metadata={'total_pages': 319, 'page': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='dd4b8756-4215-48ea-b16f-647d5e6fccbd', node_type=None, metadata={'total_pages': 319, 'page': 10}, hash='684e4f4438e05f38a818d7df62cf57a6f2f4e98f5c1474926aff47e1ef44b824'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='51654934-580b-42cd-89e2-472eba9456cf', node_type=None, metadata={'total_pages': 319, 'page': 10}, hash='de0420f93b61bc3355c6030c6f3675cd96882aeb0c428b52379bad7e94ead9f2')}, hash='9d25e490170a3b4976607ac5236f9178a03876a9cfc3d0ae48c4091454c4a0a0', text='Due to risk minimisation\nmeasures and in line with CAAS restrictions on single engine operations\nin Singapore, EC operations are typically restricted to LATA, SBAB and\nSAFTI Low Flying Area (LFA). The procedures for EC departure to\nSAFTI are unique with the principle consideration for all operations being\nthe ability to conduct an autorotative landing to designated Forced\nLanding Areas (FLAs) or to within the confines of the airbase (See Annex\nA of Chapter 22 for details) when operating in SBAB (or other bases if\napplicable). This consideration is vital and will always need to be catered\nfor in all training flights in the EC.\n1.15\nTaxy back and shut-down. Prior to taxy back to the requested or assigned\nparking bay, it is vital to maintain a good lookout for any vehicles, aircraft with\n4 While the EC has a shrouded tail rotor, it is standard practice that personnel avoid the tail rotor area completely\nfor conventional helicopters.\n1-5\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='dc8161a1-44db-4100-af51-fbd108e1660f', embedding=None, metadata={'total_pages': 319, 'page': 11}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='9be080dc-e36c-4521-a278-e24dfff97d5b', node_type=None, metadata={'total_pages': 319, 'page': 11}, hash='5631ba7e1f2abe5798de573dc0bc48bcfcc7a5010537a241c310eb4e6eaf52b6'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='c43c3f1c-da50-4b05-8dc4-a9fa4cbcae98', node_type=None, metadata={'total_pages': 319, 'page': 11}, hash='036c0b8614bb09c64e02a4850e47be0310c8059d1bc3cb77b34b575ec80005e3')}, hash='3b179c3c9aaaed638eaf2682426fe983058524f02b9ef3919b060130b28292b1', text="OFFICIAL (CLOSED)\nslow rotors, loose articles or potential FOD in the dispersal. These include, but\nare not limited to, tools, open panels/doors, carts and vehicles. Crew must ensure\nthat these items do not pose a hazard during the taxy in and verify with the captain\nprior to proceeding with the taxy in to the parking bay. Post landing, check the\nsurrounding bays for other helicopters taking off or landing before retarding Twist\ngrip from IDLE to OFF to prevent the possibility of blade sailing. Crew are to\nnote down the figures5 on the VEMD and check for any VEMD messages before\nswitching the BAT EPU off. It is the captain's responsibility to inform the ground\ncrew of the (1) presence of any VEMD messages, (2) any running T/O or landing\nfor skids inspection and (3) any other anomalies experienced in flight.\n1.16 Engine compressor rinse. A compressor rinse procedure (refer to EC120B\nSOP and SO) will be conducted after the last flight of the day.\nPOST FLIGHT ADMINISTRATION\n1.17\nFlight equipment. The GPS and DVR must be returned to MOC and SQN\nOps room respectively.\n1.18\nSigning In. All sorties must be signed in with the appropriate Actual Time\nof Departure (ATA) and Actual Time of Arrival (ATA) in the Aircraft Tech Log.\nAircrew are then to clock flight hours as per the AFOD and check off any\nrequirements or events completed in flight on the OMS.\n1.19 Flight debrief. The flight debrief serves as a dedicated time for the crew\nto share, discuss and sieve valuable lessons encountered in flight with the key\nobjective being to improve performance on subsequent flights. Any significant\nlessons learnt, deviations or safety points must be briefed to the SXO.\na.\nOpen reporting. It is imperative that lessons learnt and areas for\nimprovement be shared with all to ensure operations can be improved and\npotential gaps addressed. To encourage open reporting, crew should not\nfeel obliged to share their lessons learnt during the SQN end of day brief.", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='c43c3f1c-da50-4b05-8dc4-a9fa4cbcae98', embedding=None, metadata={'total_pages': 319, 'page': 11}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='9be080dc-e36c-4521-a278-e24dfff97d5b', node_type=None, metadata={'total_pages': 319, 'page': 11}, hash='5631ba7e1f2abe5798de573dc0bc48bcfcc7a5010537a241c310eb4e6eaf52b6'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='dc8161a1-44db-4100-af51-fbd108e1660f', node_type=None, metadata={'total_pages': 319, 'page': 11}, hash='3b179c3c9aaaed638eaf2682426fe983058524f02b9ef3919b060130b28292b1')}, hash='036c0b8614bb09c64e02a4850e47be0310c8059d1bc3cb77b34b575ec80005e3', text='The RSAF Just Culture will be applied in determining any further course\nof action. The general structure for sharing would be; (1) Sortie details\nand time, (2) Occurrence / error, (3) Root cause, (4) Lessons learnt and (5)\nFix or suggestions to avoid a repeat occurrence.\n1.20\nUpdate to training progress. It is mandatory for RWC trainees and crew\non course to update their individual progress charts and grade folders after debrief\n5 The figures required are Fuel remaining, NG, NF, total NG and total NF.\n1-6\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='e4367898-64fe-4331-bf52-6a118c6d96ad', embedding=None, metadata={'total_pages': 319, 'page': 12}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='e2af57be-6994-4987-9e26-8439dfa91698', node_type=None, metadata={'total_pages': 319, 'page': 12}, hash='75fcfb0a69d7d463903aee161c6bc498e27a2812e604fe50c8f9e27900613492')}, hash='75fcfb0a69d7d463903aee161c6bc498e27a2812e604fe50c8f9e27900613492', text='OFFICIAL (CLOSED)\nto facilitate planning for the subsequent day. QHIs are to inform trainees / pilots\nof a marginal or below score for their flight to ensure the timely follow on of\nnecessary administrative actions. Trainees who have failed or met unsatisfactory\nperformance criteria are to update their course commander and the scheduler at\nthe soonest opportunity to ensure the necessary follow on action is taken. It is vital\nthat trainees and crew take ownership of their own progress and as such will be\nheld accountable for lapses due to poor monitoring or not updating relevant\nadministrative details.\n1.21\nGradesheets. Writing gradesheets is an extremely important aspect of\nperformance monitoring and performance improvement. The gradesheet will be\nused by the trainee or crew to gain an appreciation of his/her strengths and\nweaknesses. It will also show how they are progressing at a given point in time.\nThe gradesheet will also be used by other QHIs for subsequent sorties to\ndetermine how the trainee is doing, and the areas that require more focus. Trainees\nshould receive their gradesheets from instructors within one working day after\nflight. More details can be found in the RSAF RWC Syllabus and the Flying\nInstructor handbook on grading and gradesheet writing.\nCONCLUSION\n1.22\nThe above information provides a generic guide on the typical\nadministration and conduct of flying training on the EC120B. Due to evolving\ncircumstances, the information may require further additions or deviations. Crew\nmust consult their relevant supervisors if unsure in such circumstances. In\naddition to the above, it is critical for all aircrew to operate the EC120B i.a.w. the\nFRC and in adherence to the relevant manuals, orders and publications thereby\nensuring safe, efficient and effective training and operations.\n1-7\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='4968c592-2014-4566-a90a-e62a86807fb6', embedding=None, metadata={'total_pages': 319, 'page': 13}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1c8e20a9-4034-4b6f-ba4d-57447bf022ef', node_type=None, metadata={'total_pages': 319, 'page': 13}, hash='25e8af0cbd7fcdb9032cd8b7ac677bf58f7ce87befd399409cb14bb78f7b236c')}, hash='25e8af0cbd7fcdb9032cd8b7ac677bf58f7ce87befd399409cb14bb78f7b236c', text="OFFICIAL (CLOSED)\nANNEX A\nTO EEM CHAPTER 1\nRSAF EC120B COLIBRI\nGENERAL\n1A.1 The RSAF operated EC120B (EC) is a semi-glass cockpit, single pilot,\nsingle engine basic helicopter. It is approved to operate in day and night VFR\nonly. It has a maximum AUW of 1715kg and can carry up to five persons on\nboard.\nAIRFRAME CHARACTERISTICS\n1A.2 Main rotor. The EC's main rotor turns clockwise when viewed from the\ntop of the helicopter, causing an anti-clockwise torque reaction which would\nrequire an opposing thrust force to counteract the spinning tendency of the\nfuselage (See Figure 1A-1). This thrust force is produced by the tail rotor which\ncomes in the form of a shrouded (Fenestron) tail rotor on the EC.\nFigure 1A-1: Torque reaction\nDirection of\nBlade\nRotation\nTorque\nReaction\nTail Rotor\nThrust Force\n1A.3 Fenestron tail rotor. The Fenestron tail rotor, is a high speed, variable pitch\nducted fan mounted in a cambered fin. The trademarked anti-torque system differs\nfrom a conventional tail rotor in that it typically has several additional rotor blades\nthat are smaller in size but rotate at much higher speeds. With reference to Fig\n1A-2, the EC's Fenestron tail rotor consists of a dynamic section (tail rotor hub\nand blades) and a fixed section (the stator and TGB support). The fixed section\n1-A-1\nOFFICIAL (CLOSED)", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='d33ee3f0-5a23-403a-860e-96d5b26cfe71', embedding=None, metadata={'total_pages': 319, 'page': 14}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='a979fa9b-9b51-45b9-80d6-ae7988e97121', node_type=None, metadata={'total_pages': 319, 'page': 14}, hash='c497945054b0f50d09fbcb14dd22cbfdc146ea7fe91b99560209f943d23be6ed')}, hash='c497945054b0f50d09fbcb14dd22cbfdc146ea7fe91b99560209f943d23be6ed', text="OFFICIAL (CLOSED)\nhas seven stator vanes that assist in straightening and guiding the air flow for the\noptimum AOA on the rotor blades. The dynamic section has 8 asymmetrically\nspaced rotor blades that rotate clockwise (when viewed from the port side) in a\n'Union Jack' arrangement to optimize performance and reduce noise. Controlling\nthe thrust of the Fenestron is done in the same way as a conventional tail rotor\nsystem. The pilot's pedal inputs changes the pitch of all the tail rotor blades\nthrough a mechanical linkage to the tail gearbox. The tail rotor design has several\nimprovements over a regular tail rotor:\na.\nCreates an aerodynamically efficient design that produces smaller\ntip vortices on the ends of the rotor blades, reducing drag which in turn,\nmaximizes thrust produced.\nb.\nSignificantly reduces noise compared to a traditional tail rotor.\nc.\nShrouded design allows for a safer working area for crews with\nrotors turning.\nd.\nShrouded design helps minimise tail rotor strikes when landing at\nunprepared landing sites.\nFigure 1A-2: Fenestron tail rotor\nSTARBOARD\nPORT\nS/N1433\nSTATOR\nVANES\nTAIL ROTOR\nBLADES\nS/N1444\n1-A-2\nOFFICIAL (CLOSED)", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='842bd7d8-e1ba-44d6-ac96-247bd9a0d6d7', embedding=None, metadata={'total_pages': 319, 'page': 15}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='2af926d2-6129-4fe4-b2f4-a09df5e94c13', node_type=None, metadata={'total_pages': 319, 'page': 15}, hash='76c0193bd644f59d81afdbffe7cdc7312c6ab680a5f997bde94a145c6de0434a')}, hash='76c0193bd644f59d81afdbffe7cdc7312c6ab680a5f997bde94a145c6de0434a', text="OFFICIAL (CLOSED)\n1A.4 Horizontal Stabilizer. Located on the tail boom, the horizontal stabilizer\nis designed with a negative camber to provide pitch axis stability for the aircraft.\nIn forward flight, when the cyclic disc is tilted forward, the fuselage acts\npendulously below the main rotor, causing the aircraft attitude to pitch\ndownwards. The negative camber of the horizontal stabilizer then damps this\nmovement by creating an opposing downward force to keep the fuselage at a more\nlevel attitude to minimise parasitic drag and widen the CG range of the aircraft.\nIn a hover, the stabilizer's stability helps prevent the fuselage from following\nthrough when a gust of wind causes the rotor disc to flap back. As the fuselage\nbegins to pitch up, the increasing angle of attack on the stabilizer will damp down\nthe movement and the rearward tilt of the disc will be greatly reduced.\nNonetheless, it is important to note that as a result of the main rotor downwash\nexerting a force on the tail stabilizer causing a tail-down moment, the helicopter\nin the hover generally adopts a nose-up attitude. In rearward flight or tailwind\nconditions, caution must be exercised as the horizontal stabilizer can press the tail\ndownward, resulting in a tail strike.\nFigure 1A-3: Horizontal stabilisier\nGurney\nFlap\nNegative\nCamber\n1A.5 Gurney flaps. These are positioned on the trailing edge of the stabilizer\nperpendicular to the airflow. They increase the camber of the stabilizer and\nincrease the coefficient of lift, just like how a flap does. This enhances the\nnegative lift effects of the stabilizer which improves the overall pitch stability.\nThe port side gurney flap is oriented downwards while the starboard side is\noriented upwards in the EC120B to create differential lift to counter the rolling\nmoment (to the advancing side) that is caused by inflow roll.\n1A.6 Vertical tail fin. The fenestron is different in that the aerofoil section of\nthe cambered fin acts like a vertical stabilizer to unload the work of the anti-torque\n1-A-3\nOFFICIAL (CLOSED)", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='572869ae-98ce-4346-a1f3-938fcdba57d2', embedding=None, metadata={'total_pages': 319, 'page': 16}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='53b9185e-d06e-4522-ae7c-95b16d369abc', node_type=None, metadata={'total_pages': 319, 'page': 16}, hash='59c8d416da5528cc0c58d4acef282191ebee788f05d6386815e5217ad3a2b0d3')}, hash='59c8d416da5528cc0c58d4acef282191ebee788f05d6386815e5217ad3a2b0d3', text="OFFICIAL (CLOSED)\nsystem. With reference to Figure 1A-4, the fin structure is responsible for a\nsignificant amount of the thrust produced by the tail rotor as some of it is produced\nby the low pressure on the intake side acting on the side of the fin. Consequently,\nas airspeed increases, the tail rotor will require less power as a result of the\nincreasing thrust generated by the tail fin. This is important as in an event of an\nanti-torque system failure, the vertical tail fin will aid in trimming the helicopter\nin flight, providing some amount of directional control to allow the pilot to\nmanoeuvre the helicopter for a safe forced landing. The tail rotor's effectiveness,\nthrough a reduction in the anti-torque (right) pedal requirement, can be felt as the\nairspeed passes 40kts.\nFigure 1A-4 Vertical fin\nSome thrust due\nto low pressure\non this surface\nFin\nVertical Tail Fin\nMulti-blade\nvariable-pitch fan\nBumper\nCOCKPIT INSTRUMENTS\n1A.7 The instrument layout is as depicted in Figure 1A-5. Some key items to\ntake note of are:\na.\nCaution and warning panel (CWP). Notifies the pilots when a\nsystem or function fails through; (1) Red warning lights for alarms which\nrequire immediate action, and (2) Amber caution lights for alarms\nrequiring action which can be delayed.\nb.\nPrimary flight display (PFD). Located in front of the right seat, it\ndisplays the primary flight instrumentation data from the on-board Air\nData and Attitude Heading Reference System (ADAHRS).\nc.\nNavigation display (ND). Located in front of the right seat and\nbelow the PFD, it displays navigational data and can be further configured\nas a moving map or as an electronic HSI.\n1-A-4\nOFFICIAL (CLOSED)", start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
# ...
#  TextNode(id_='e3d986e1-95f3-4c62-bba8-c48b96239f0b', embedding=None, metadata={'total_pages': 319, 'page': 313}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1b60f0b6-0d12-4c64-bcad-42e5b72c66ee', node_type=None, metadata={'total_pages': 319, 'page': 313}, hash='4119db285557175dcfde83c0a97e8112d0fd44cdcb6bd00bd39880587fedc2b4'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='734fb09b-fe17-4e79-acab-8ca829520f49', node_type=None, metadata={'total_pages': 319, 'page': 313}, hash='0775aaccc740e02eee5f5ff0d495b09ac8fea918df0e85d735450c9885aede41')}, hash='0bedad7377f6b0ff91a30321b0f6f15bc6c19393b018d9ac0fa13c5ff12d3e35', text='OFFICIAL (CLOSED)\n22.43 BATTERY FAILURE\na.\nThere are a total of two batteries located at the baggage\ncompartment. If the "BATT" light is illuminated, it means both batteries\nare off-line. For this emergency, will first check if the [BAT EPU] is\nturned on.\nb.\nIf no, turn the [BAT EPU] on and if light goes out, continue flight.\nc.\nIf yes, perform an electrical reset by pressing on the [ELECT\nRST] switch on the LACU. If the "BATT" Light goes out, continue flight.\nd.\nIf the "BATT" light remains on, carry out a LAND AS SOON\nAS PRACTICABLE. Carry out normal shutdown procedure after\nlanding.\nFLIGHT CONTROL EMERGENCIES\n22.44 HYDRAULIC POWER FAILURE IN FLIGHT\na.\nThe helicopter hydraulic system is designed to ease control loads\nand allow for easier manipulation of flight controls. "HYDR" light comes\non when the hydraulic pressure drops to ≤20 bars. This could be due to\nhydraulic pump failure and may result in stiffening of flight controls.\nShould there be a malfunction, the accumulators contain sufficient\npressure to secure flight and to reach the hydraulic failure safety speed.\nHowever, crew are to note that the intensity and direction of controls\nfeedback force may vary considerably and this may result in poor the\nhelicopter control and even loss of control.\nb.\nIn the event of this emergency occurring in flight, adjust airspeed\nto Vy prior to switching off the hydraulic via the HYD cut-off switch. This\nwill avoid large movements on the cyclic and collective due to the default\nsetting when the hydraulic system is switched off. This will result in much\nhigher control loads on the cyclic and collective. Recover to the nearest\nsuitable landing area without delay to conduct power on landing. An\nimportant consideration is to select an area (e.g.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='734fb09b-fe17-4e79-acab-8ca829520f49', embedding=None, metadata={'total_pages': 319, 'page': 313}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='1b60f0b6-0d12-4c64-bcad-42e5b72c66ee', node_type=None, metadata={'total_pages': 319, 'page': 313}, hash='4119db285557175dcfde83c0a97e8112d0fd44cdcb6bd00bd39880587fedc2b4'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='e3d986e1-95f3-4c62-bba8-c48b96239f0b', node_type=None, metadata={'total_pages': 319, 'page': 313}, hash='0bedad7377f6b0ff91a30321b0f6f15bc6c19393b018d9ac0fa13c5ff12d3e35')}, hash='0775aaccc740e02eee5f5ff0d495b09ac8fea918df0e85d735450c9885aede41', text='airfield) that would permit\na slow running landing (at around 10kts) as it was cautioned in the FLM\nthat hover flight and low speed manoeuvre may result in poor the\nhelicopter control and possible loss of control for this emergency. If a\nhydraulic leak is suspected, FP may elect to land at the nearest FLA as\nthere is a potential risk of a fire.\n22-18\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='64aaaea7-4ef9-4fc7-b774-fe5bb087c4a0', embedding=None, metadata={'total_pages': 319, 'page': 314}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='09e6a7d8-9b48-4376-b17a-04d0200a6ade', node_type=None, metadata={'total_pages': 319, 'page': 314}, hash='3da40183361e0b363e879a56ebe09c8f16fb7a29880f9acc479cea912dd9932a'), <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(node_id='bd6b812f-bed4-41f9-93b2-6c628beec130', node_type=None, metadata={'total_pages': 319, 'page': 314}, hash='9078305b1716328a80498df96c5598f679c7cc6735e1e7fceb7309f9983fb6b9')}, hash='6ac28dd845e0b90585439f9139589a596cd058b8fa8e5cc69fda73758a591263', text='OFFICIAL (CLOSED)\n22.45 HYDRAULIC POWER FAILURE IN HOVER (IGE/OGE)\na.\nCarry out a LAND AS SOON AS POSSIBLE. "PAN" call and\nset IFF set to "EMERG. Carry out normal shutdown after landing.\n22.46 FLIGHT CONTROL HARDOVER/SERVO JAM IN HOVER\na.\nCarry out a LAND IMMEDIATELY. "MAYDAY" call and set\nIFF set to "EMERG. Carry out normal shutdown after landing.\n22.47 FLIGHT CONTROL HARDOVER/SERVO JAM IN FLIGHT\na.\nAdjust airspeed to Vy prior to switching off the hydraulic via HYD\ncut-off switch. This will avoid large movement on the cyclic and\ncollective due to the default setting when the hydraulic system is switched\noff. The same consideration for the landing area as Hydraulic failure will\napply. Carry out a LAND AS SOON AS POSSIBLE, "MAYDAY" call\nand set IFF set to "EMERG. Carry out a normal shutdown after landing.\nFUEL EMERGENCIES\n22.48 FUEL PRESSURE LOW\na.\n"FUEL P" light will illuminate on the CWP when the fuel\npressure supplied to the engine is less than 0.2 bar. Lower the collective\nto reduce the fuel demand for the engine and turn on [FUEL P] which is\nlocated at LACU. By turning on [FUEL P], it will activate the booster\npump which should help to increase the fuel supply to the engine. "PAN"\ncall is to be made and carry out a LAND AS SOON AS POSSIBLE with\npower-on landing. IFF select to "EMERG". Consideration is to minimise\npower usage for landing and be prepared for engine flame-out due to\nstarvation of fuel to the engine.\n22.50 LOW FUEL LEVEL WARNING\na.\n"FUEL" light comes on when the level of fuel drops below 30kg.\nVerify the level of fuel indicated on the VEMD.', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='bd6b812f-bed4-41f9-93b2-6c628beec130', embedding=None, metadata={'total_pages': 319, 'page': 314}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='09e6a7d8-9b48-4376-b17a-04d0200a6ade', node_type=None, metadata={'total_pages': 319, 'page': 314}, hash='3da40183361e0b363e879a56ebe09c8f16fb7a29880f9acc479cea912dd9932a'), <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(node_id='64aaaea7-4ef9-4fc7-b774-fe5bb087c4a0', node_type=None, metadata={'total_pages': 319, 'page': 314}, hash='6ac28dd845e0b90585439f9139589a596cd058b8fa8e5cc69fda73758a591263')}, hash='9078305b1716328a80498df96c5598f679c7cc6735e1e7fceb7309f9983fb6b9', text='The fuel level should\ncorrespond to the indication in CWP as the fuel quantity signals are from\nsame fuel probe. Carry out a LAND AS SOON AS POSSIBLE and make\na "MAYDAY" call. IFF set to "EMERG". Do note that 15mins of flight\ntime remains at MCP. Avoid sideslip over 15° as there is only one fuel\nsupply line to the engine which is located on the aft port side of the lower\n22-19\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='b0796fde-8135-4dd8-be68-81ca60d31941', embedding=None, metadata={'total_pages': 319, 'page': 315}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='61bd5beb-04d4-445a-9117-897bb163e71b', node_type=None, metadata={'total_pages': 319, 'page': 315}, hash='5ba223fe79d16180ddb20e115a7cd77be2b4d5b63b237ca9e7b5172669fbd31b')}, hash='5ba223fe79d16180ddb20e115a7cd77be2b4d5b63b237ca9e7b5172669fbd31b', text='OFFICIAL (CLOSED)\nfuel tank. If the helicopter sideslips, it might cause fuel starvation and\ncould result in engine failure.\n22.51 FUEL FILTER CLOG\na.\nIllumination of "FUEL FILTER" is likely due to the\ncontamination of fuel which leads to the clogging of the fuel filter. The\nopening of the fuel filter by-pass might induce NG oscillations, limited\npower or possible flame-out.\nb.\nFP should lower the collective to reduce the fuel demand for the\nengine and carry out LAND AS SOON AS POSSIBLE with power-on\nlanding. "PAN" call is to be made and select IFF to "EMERG".\nc.\nIF NG oscillations occur, check if NR is in normal range. If yes,\ncarry out LAND AS SOON AS POSSIBLE. If no, refer to the\nGOVERNOR FAILURES check list. Refer to 22.25/26 for GOVERNOR\nFAILURES procedures.\nd.\nIn the event that "FUEL FILTER" goes out upon lowering of the\ncollective, continue to fly at the reduced speed and carry out LAND AS\nSOON AS PRACTICABLE with power-on landing.\nINDICATION EMERGENCIES\n22.52 VEMD FAILURE (ONE SCREEN)\na.\nWhen encountering this emergency, turn off the failed screen and\nread all information on the other screen.\n22.53 VEMD FAILURE (BOTH SCREENS)\na.\nIf both screens failed, first make a "PAN" call. Thereafter to avoid\nany power overlimit, the maximum authorised power will be the power\nneeded to establish level flight with IAS at 100kts at OHp. Carry out a\nLAND AS SOON AS PRACTICABLE. Carry out a zero speed/running\nlanding and normal shutdown.\n22-20\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='acc99493-bb27-47cc-a640-58ae77dae485', embedding=None, metadata={'total_pages': 319, 'page': 316}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='cc0a6fcc-1eb0-4044-9045-e0038526e110', node_type=None, metadata={'total_pages': 319, 'page': 316}, hash='7342db7dbec734d4d942585fd0b48f8a92961841d4b2ee675b33a4045602aaa4')}, hash='7342db7dbec734d4d942585fd0b48f8a92961841d4b2ee675b33a4045602aaa4', text='OFFICIAL (CLOSED)\nABNORMAL VIBRATION EMERGENCIES\n22.54 ABNORMAL VIBRATION (HOVER)\na.\nAbnormal/unusual vibrations in the helicopter might be an\nindication of impending failure of the flight controls or damage to the main\nor tail rotor.\nb.\nWhen encountering this emergency in a hover, land the helicopter\nimmediately. Make a "MAYDAY" call. Complete the emergency\nshutdown after landing.\nc.\nTo prevent the occurrence of ground resonance post landing, crew\nmay elect to land and shutdown over a grassy area (such as the lanes)\nwithin the airbase.\n22.55 ABNORMAL VIBRATION (FLIGHT)\na.\nFor this emergency, FP should attempt to reduce the vibration by\nlowering the collective. In addition, adjust airspeed to reduce vibrations.\nIf the vibrations have lessened, crew can maintain the airspeed and power\nsetting and recover to base. A "PAN" call should be declared. If vibrations\nremain excessive declare a "MAYDAY", set IFF to "EMERG" and\nLAND AS SOON AS POSSIBLE. Actions to be carried out for the\nlanding should be smooth and gentle. Complete emergency shutdown\nafter landing.\nTOTAL RADIO FAILURE (NORDO)/TOTAL ELECTRIC FAILURE\na.\nThis write-up describes the additional considerations that should\nbe undertaken by crew in the event of a Total Radio Failure\n(NORDO)/Total Electric Failure during flight, on top of the procedures\nlisted in the RSAF ATCI.\nb.\nDuring Total Radio Failure (NORDO), the EMER/ NORM toggle\nswitches on the N335 Inter-Comm panels are to be selected to EMER.\nVerify that the EMERG LED is illuminated\nc.\nShould crew experience a total electrical failure, apart from the\nloss of radio and intercom, the helicopter will lose the VEMD and EFIS\nwhich. Only the pitot-static instruments and the NR indicator tape that\ndisplays the NR would be working. While the engine may still be\n22-21\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='86b781d4-e7fa-40d2-879b-6c084358e14b', embedding=None, metadata={'total_pages': 319, 'page': 317}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='8199132b-5f36-4e72-9390-88fa0920c68d', node_type=None, metadata={'total_pages': 319, 'page': 317}, hash='d3633a8cebb9bab931567eecfa61ebb2953dcd2a7d0e66b8b2e819f4f5d0c0eb')}, hash='d3633a8cebb9bab931567eecfa61ebb2953dcd2a7d0e66b8b2e819f4f5d0c0eb', text='OFFICIAL (CLOSED)\nperforming normally, crew will not know of any impending emergency\nthat is displayed via the CWP. The engine also cannot be restarted in-\nflight. For day, carry out LAND AS SOON AS POSSIBLE and terminate\nwith a power-on landing. For night due to the lack of illumination, recover\nthe helicopter back to base and terminate with a power-on landing. The\nuse of the torch light will be required during night flying to illuminate the\ninstrument panel to aid the flying pilot.\nd.\nDuring shut down, the twist grip would not be able to retard to\nshut-off detent due to lack of electrical power to the plunger. Hence, crew\nare to shut down using the fuel shut-off lever.\n22-22\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='e70d686a-bf08-4bdc-b199-7c2ca7dd9573', embedding=None, metadata={'total_pages': 319, 'page': 318}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='4d40c477-a0e5-413f-96f7-9a911972a9ed', node_type=None, metadata={'total_pages': 319, 'page': 318}, hash='b838e20707dd02d166e6c9c2534829a94d70b532df7c0f2882a23cf250621656')}, hash='b838e20707dd02d166e6c9c2534829a94d70b532df7c0f2882a23cf250621656', text='OFFICIAL (CLOSED)\nAUTOROTATIVE RANGE TO AUTHORISED FLAS IN TRAINING AREAS\nANNEX A TO\nCHAPTER 22\nWoodlands Checkpoint\nO\nLegend:\nO\n: 500ft\n: 1000ft\n: 1500ft\n2000ft\nMandai Hill Camp\nBP/BT Rd Junct on\nMAC 2\no\nR168/2Nm\nPierce LP\nMayflower Garder\nO\n· Lower Pierce Reservoir Dam\nWindsor Park Estate\nChantek\nLATA A and SBAB\nMacritchie Dam\n3D\nBt Timah Hill\n22-A-1\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n'),
#  TextNode(id_='e3b7c6d4-2dcc-467c-accb-086338b8e2cb', embedding=None, metadata={'total_pages': 319, 'page': 319}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='7ba04cef-d599-4e34-b630-098bc3ffe502', node_type=None, metadata={'total_pages': 319, 'page': 319}, hash='7c6c870a9bb9e3c4e5c399cd19d0e14c2015475f2fe51fcb5654c4cbfa676c62')}, hash='7c6c870a9bb9e3c4e5c399cd19d0e14c2015475f2fe51fcb5654c4cbfa676c62', text='OFFICIAL (CLOSED)\nLegend:\n: 1500ft\n: 2000ft\nSEAGULL\nWoodlands Checkpoint\nO\nO\nMandal Hill Camp\nTZ THR\nKC 2\nMHC 2\nPierce LP\nO\nBP/BT Rd Junction\nR168\nChantek\nSAFTI TRANSIT\n22-A-2\nOFFICIAL (CLOSED)', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')]
